# %% [markdown]
# ### Decision
# **Reference.** Smith (2020).
# **Why used.** It is the canonical choice.
# **Relevance to our results.** Governs the point estimate.
# **Connection to simulator.** Feeds the FX-vol block.

# %%
result = sm.OLS(y, X).fit()
