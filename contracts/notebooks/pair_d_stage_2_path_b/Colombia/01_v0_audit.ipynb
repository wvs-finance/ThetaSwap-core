# %% [markdown]
# # Pair D Stage-2 Path B — v0 — Data-coverage audit
#
# **Notebook ID:** `01_v0_audit`
#
# **Ladder step:** Phase 1 (Tasks 1.1 → 1.5)
#
# **Spec pin:** v1.3 sha256 `4e8905a93b1307d5f9a5b8fe76bcd5de92b6b6493627bcf28d8e8bdf0fdd6bea`
#
# **Plan pin:** `contracts/docs/superpowers/plans/2026-04-30-pair-d-stage-2-B-on-chain-data-implementation.md`
#
# **Stage-1 pin chain (READ-ONLY):**
# - `pair_d_spec_v1_3_1`: `964c62cca0be1b9070944b5398fe97886c6d07d37ba7121199de8ccc341ef659`
# - `panel`: `6d7d9e60dad1715ce86e8adb7b3d44ba236d0b063796293b40575994a9363edf`
# - `verdict`: `1efd0e34d7c1af821c8528a7bc895a63e1dc5e1c289f3b6a1b2d392ba59806cf`

# %% [markdown]
# ## Citation discipline
#
# Per memory `feedback_notebook_citation_block` (NON-NEGOTIABLE), every test / decision /
# spec choice in this estimation or sensitivity notebook is preceded by a 4-part markdown
# block:
#
# 1. **reference**: which spec section / FLAG / external paper / framework artifact this
#    choice is grounded in
# 2. **why used**: why this choice (over alternatives) — what the spec or framework pinned
# 3. **relevance to results**: how this choice shapes the numerical output of the cell
#    that follows
# 4. **connection to simulator**: how the result feeds the cross-path Path A v3 simulator
#    handoff (FLAG-B9 schema), the v3 backtest harness, or the Stage-2 convergence memo
#
# Per memory `feedback_notebook_trio_checkpoint` (NON-NEGOTIABLE), this notebook is authored
# in (why-markdown → code-cell → interpretation-markdown) trios. The Analytics Reporter
# authoring this notebook HALTS after every trio for orchestrator review; no bulk authoring.

# %% [markdown]
# ## Framing pin (NON-NEGOTIABLE per spec §1 + CORRECTIONS-γ)
#
# Path B's deliverable IS **structural-exposure characterization** — the cash-flow
# geometry yielding `|Δ^(a_l)|` and `|Δ^(a_s)|` magnitudes in $-notional that the
# CPO would neutralize on observed transaction flows.
#
# Path B's deliverable is NOT willingness-to-pay (WTP) for an instrument that does
# not yet exist. WTP is a Stage-3 (deployment) question requiring a different
# evidence base (deployed pilot, surveyed demand, observed take-up at posted
# prices). Path B prose that drifts into WTP-inference language is a methodology
# error and triggers HALT-disposition.
#
# `v0 deliverable: data-availability audit only; structural-exposure framing inherited.`

# %% [markdown]
# ## Scaffold notice
#
# This notebook is a Phase 0 SCAFFOLD. Trio-checkpoint authoring begins in the
# corresponding plan task (e.g., Task 2.1 / 2.2 / 2.3 / 2.4 for `02_v1_cf_al`,
# Task 3.x for `03_v2_cf_as`, Task 4.x for `04_v3_cpo_backtest`, Task 5.x for
# `05_convergence_memo`). The first authoring trio populates Section 1 below;
# orchestrator HALTs between trios per `feedback_notebook_trio_checkpoint`.

# %% [markdown]
# ## Section 0 — env import + sha-pin verify (first trio lands here)
#
# _Trio A — why-markdown placeholder. Replace with reference / why used / relevance to results / connection to simulator block in the corresponding plan task._

# %%
# placeholder — populated by trio A code cell at the corresponding plan task
from env import *  # path constants, version pins, HALT_EXCEPTIONS
import hashlib
# Spec sha-pin verify (cheap; runs every notebook open):
live_path_b_spec_sha = hashlib.sha256(PATH_B_SPEC_PATH.read_bytes()).hexdigest()
assert live_path_b_spec_sha == PATH_B_SPEC_SHA256, (
    f'PATH_B_SPEC sha mismatch: live={live_path_b_spec_sha} pinned={PATH_B_SPEC_SHA256}'
)
print('PATH_B spec v1.3 sha verified clean')

# %% [markdown]
# _Trio A — interpretation-markdown placeholder. Replace with the trio's interpretation in the corresponding plan task; HALT after authoring this cell.
