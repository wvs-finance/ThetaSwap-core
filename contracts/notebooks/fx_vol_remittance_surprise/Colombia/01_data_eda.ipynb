# %% [markdown]
# # Phase-A.0 — Remittance-surprise → TRM RV (Colombia)
#
# **Notebook 1 of 3**: EDA + panel-fingerprint extension (Phase-1 decision-hash extension of the Rev-4 frozen 947-obs panel with the remittance primary RHS + auxiliary columns).
#
# This notebook is part of the Phase-A.0 structural-econometric exercise testing whether the Colombian aggregate-monthly remittance AR(1) surprise carries detectable information content for COP/USD weekly realized volatility, on the frozen 947-observation weekly panel.
#
# Spec: `contracts/docs/superpowers/specs/2026-04-20-remittance-surprise-trm-rv-spec-rev1.md`
# Plan: `contracts/docs/superpowers/plans/2026-04-20-remittance-surprise-implementation.md`

# %% [markdown]
# ## Anti-fishing framing (Rev-1 spec §10)
#
# This exercise tests a **distinct macro mechanism** (external-inflow channel) from the prior CPI-surprise Rev-4 exercise (inflation channel). It is **NOT a rescue** of the CPI-FAIL verdict (2026-04-19).
#
# Provenance: the corpus file `/home/jmsbpp/apps/liq-soldk-dev/notes/REMITTANCE_VOLATILITY_SWAP/REMITTANCE_VOLATILITY_SWAP.md` has mtime **2026-04-02**, predating the CPI-FAIL verdict (2026-04-19) by 17 days — establishing remittance as a pre-existing candidate mechanism before the CPI exercise was run, not a post-hoc rescue target.
#
# Gate: two-sided T3b at α=0.10 on β̂_Rem = OLS coefficient on the remittance AR(1) surprise, with HAC Newey-West SE (Bartlett kernel, Andrews 1991 AR(1) plug-in bandwidth). Verdict enum: PASS / FAIL / INCONCLUSIVE (the INCONCLUSIVE verdict, per spec §4.5, distinguishes underpowered null from mechanism absence using a 0.20-SD MDES threshold).

# %% [markdown]
# ## Gate Verdict
#
# *populated after NB2 and NB3 — this cell is overwritten by the Task 24 README auto-render via `render_readme.py`.*
